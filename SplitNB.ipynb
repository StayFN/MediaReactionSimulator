# %%
import pandas as pd

df = pd.read_csv("csv\output\Report_Shorts_with_summary_stefan.csv")

# %%
df.head()
# Out:
#       Video ID                                        Video Title  \
# 0  4QP5CvHB1s0  b'Neymar provocation \xf0\x9f\xa4\xab\xf0\x9f\...
# 1  4ChtDj7GpIc  b"Rescued kitten's provocation! Inspired by a ...
# 2  qJU8I4KWpJs  b"\xf0\x9f\x90\xb1 Paws & Provocation | Rescue...
# 3  06YOF1p-2Xw  b'La provocation ultime \xf0\x9f\x98\x82\xf0\x...
# 4  SQYkxbDVxGQ  b'CONTROL YOURSELF UNDER PROVOCATION -  ENCHIR...
#
#                                        Channel Title  \
# 0                                      b'FunChannel'
# 1  b'\xe3\x81\xad\xe3\x81\x93\xe3\x81\xb1\xe3\x82...
# 2  b'\xe3\x81\xad\xe3\x81\x93\xe3\x81\xb1\xe3\x82...
# 3                                     b'Tasawar ato'
# 4                                    b'Stoic Sanity'
#
#                                           Transcript  Duration  \
# 0                             songs [Music] [Music]      9.198
# 1                                       [Music] for     19.220
# ...

# %%
# Find the indices where the search term changes
provocation_end_index = df[df['Video ID'] == 'q5ZmcUlYsos'].index[0]
sexy_end_index = df[df['Video ID'] == 'be4ns7vfZDY'].index[0]

# Split the DataFrame into three based on the search terms
df_provocation = df.iloc[:provocation_end_index + 1]
df_sexy = df.iloc[provocation_end_index + 1:sexy_end_index + 1]
df_sexist_joke = df.iloc[sexy_end_index + 1:]

# Now, you have three separate DataFrames, each containing rows for one of the search terms.

# %%
df_provocation.head()
# Out:
#       Video ID                                        Video Title  \
# 0  4QP5CvHB1s0  b'Neymar provocation \xf0\x9f\xa4\xab\xf0\x9f\...
# 1  4ChtDj7GpIc  b"Rescued kitten's provocation! Inspired by a ...
# 2  qJU8I4KWpJs  b"\xf0\x9f\x90\xb1 Paws & Provocation | Rescue...
# 3  06YOF1p-2Xw  b'La provocation ultime \xf0\x9f\x98\x82\xf0\x...
# 4  SQYkxbDVxGQ  b'CONTROL YOURSELF UNDER PROVOCATION -  ENCHIR...
#
#                                        Channel Title  \
# 0                                      b'FunChannel'
# 1  b'\xe3\x81\xad\xe3\x81\x93\xe3\x81\xb1\xe3\x82...
# 2  b'\xe3\x81\xad\xe3\x81\x93\xe3\x81\xb1\xe3\x82...
# 3                                     b'Tasawar ato'
# 4                                    b'Stoic Sanity'
#
#                                           Transcript  Duration  \
# 0                             songs [Music] [Music]      9.198
# 1                                       [Music] for     19.220
# ...

# %%
df_sexy.head()
# Out:
#        Video ID                                        Video Title  \
# 47  ATx-hlfK9o4       b'Every guys dream \xf0\x9f\x98\x82 #shorts'
# 48  tfSoHecAcqI                               b'sexy girl #shorts'
# 49  A8ZWqpTJtsk  b'Hot Dog Prank Goes Wrong! \xf0\x9f\xa4\xa3 #...
# 50  lThaG-9QRxg  b'Sex drive 8000000% - Tuesday   #wifelike #pa...
# 51  HwnXVOjLIjQ  b'\xf0\x9f\x98\x86\xf0\x9f\x91\x8f Birthday Ce...
#
#                Channel Title  \
# 47         b'Isaiah Miranda'
# 48             b'Pov Sunhai'
# 49             b'Neil Henry'
# 50  b'The.Wildwild.Universe'
# 51             b'Joytimisty'
#
#                                            Transcript  Duration  \
# 47  oh take a picture it'll last longer I wasn't l...    89.080
# 48  [Music] you can't jump out of the car right no...    32.720
# 49  foreign [Music] [Music] Jay Josh [Music] you'r...    49.207
# 50                         William sex drive [Music]     12.581
# ...

# %%
df_sexist_joke.head()
# Out:
#        Video ID                                        Video Title  \
# 94  R1ENVua_zcQ  b'ANTHONY JESELNIK Sexist Joke \xf0\x9f\x98\x8...
# 95  _RiXWwbG5GQ  b'r@cist or s3xist, one has to go. which one y...
# 96  VbJCDHtrGEI  b"That sexist joke by Michael Che tho....was p...
# 97  8zm_4eShsSQ  b'the most r@cist joke ever #shorts #comedy #f...
# 98  XqnwQKLe--8  b'He wanted IT SO BAD!\xf0\x9f\x98\x8f\xf0\x9f...
#
#         Channel Title                                         Transcript  \
# 94  b'Comedic Genius'  I was in a bar last night and saw this beautif...
# 95        b'al jokes'  okay so if you take this pill you can be racis...
# 96        b'PS edits'  New York City is not requiring employers to di...
# 97        b'al jokes'  I have here the most racist joke ever did I se...
# 98        b'StarVuks'                            no you can't have that
#
#     Duration  Words per Second  Number of Comments  \
# 94    46.841          1.494417                  31
# ...

# %%
len(df)
# Out:
# 179

# %%
print(len(df_provocation))
print(len(df_sexy))
print(len(df_sexist_joke))
# Out:
# 47
# 47
# 85

# %%
df_provocation.to_csv("csv\output\Report_Shorts_with_summary_stefan_provocation.csv", index=False)
df_sexy.to_csv("csv\output\Report_Shorts_with_summary_stefan_sexy.csv", index=False)
df_sexist_joke.to_csv("csv\output\Report_Shorts_with_summary_stefan_sexist_joke.csv", index=False)
