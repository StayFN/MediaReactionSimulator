# %%
import pandas as pd

df = pd.read_csv("csv\output\Report_Shorts_with_summary_stefan_sexy_experimentResults.csv")
df.head()
# Out:
#       Video ID                                        Video Title  \
# 0  ATx-hlfK9o4       b'Every guys dream \xf0\x9f\x98\x82 #shorts'
# 1  tfSoHecAcqI                               b'sexy girl #shorts'
# 2  A8ZWqpTJtsk  b'Hot Dog Prank Goes Wrong! \xf0\x9f\xa4\xa3 #...
# 3  lThaG-9QRxg  b'Sex drive 8000000% - Tuesday   #wifelike #pa...
# 4  HwnXVOjLIjQ  b'\xf0\x9f\x98\x86\xf0\x9f\x91\x8f Birthday Ce...
#
#               Channel Title  \
# 0         b'Isaiah Miranda'
# 1             b'Pov Sunhai'
# 2             b'Neil Henry'
# 3  b'The.Wildwild.Universe'
# 4             b'Joytimisty'
#
#                                           Transcript  Duration  \
# 0  oh take a picture it'll last longer I wasn't l...    89.080
# 1  [Music] you can't jump out of the car right no...    32.720
# 2  foreign [Music] [Music] Jay Josh [Music] you'r...    49.207
# 3                         William sex drive [Music]     12.581
# 4                  bye [Music] [Applause] thank you     13.598
#
#    Words per Second  Number of Comments  \
# 0          2.166592               20362
# 1          0.916870                  29
# 2          0.548702                 152
# 3          0.397425                 136
# 4          0.441241                8854
#
#                                       Top10 Comments             Category  \
# 0  ['If only women were this straight up', 'Plot ...     b'Entertainment'
# 1  ['Girl she&#39;s even not wearing a shirt😂😂😂',...    b'People & Blogs'
# 2  ['Youtube then: 😜😄🤣😂<br>Youtube now:😔💀💀', 'Oh ...     b'Entertainment'
# 3  ['And people say men still treat women as obje...  b'Film & Animation'
# 4  ['ज्योती आपकी ठुकाई हो रही थी तो ऐसी हि आवाज़ आ...     b'Entertainment'
#
#        Views  ...                                       Custom Query  \
# 0  107524329  ...  You are a copywriter, create a 100 word summar...
# 1     221828  ...  You are a copywriter, create a 100 word summar...
# 2    5516390  ...  You are a copywriter, create a 100 word summar...
# 3    3186779  ...  You are a copywriter, create a 100 word summar...
# 4   50352006  ...  You are a copywriter, create a 100 word summar...
#
#                                          LLM Summary  \
# 0       Isaiah Miranda's YouTube Short "#EveryGuy...
# 1        Pov Sunhai's YouTube Short "#SexyGirl" p...
# 2        Neil Henry's YouTube Short "#HotDogPrank...
# 3         The Wildwild Universe's YouTube Short "...
# 4         JoyTimisty's YouTube Short "#BirthdayCe...
#
#                           low ssc characteristics st  \
# 0  You are a person with following characteristic...
# 1  You are a person with following characteristic...
# 2  You are a person with following characteristic...
# 3  You are a person with following characteristic...
# 4  You are a person with following characteristic...
#
#                          high ssc characteristics st  \
# 0  You are a person with following characteristic...
# 1  You are a person with following characteristic...
# 2  You are a person with following characteristic...
# 3  You are a person with following characteristic...
# 4  You are a person with following characteristic...
#
#                                   low ssc defined st  \
# 0  You are a person with low state self control a...
# 1  You are a person with low state self control a...
# 2  You are a person with low state self control a...
# 3  You are a person with low state self control a...
# 4  You are a person with low state self control a...
#
#                                  high ssc defined st low ssc characteristics  \
# 0  You are a person with high state self control ...        {"sex\_stim": 2}
# 1  You are a person with high state self control ...        {"sex\_stim": 3}
# 2  You are a person with high state self control ...         {"sex_stim": 1}
# 3  You are a person with high state self control ...         {"sex_stim": 2}
# 4  You are a person with high state self control ...        {"sex\_stim": 1}
#
#   high ssc characteristics     low ssc defined      high ssc defined
# 0         {"sex\_stim": 1}    {"sex\_stim": 3}      {"sex\_stim": 1}
# 1         {"sex\_stim": 1}    {"sex\_stim": 4}      {"sex\_stim": 1}
# 2         {"sex\_stim": 1}    {"sex\_stim": 1}      {"sex\_stim": 1}
# 3         {"sex\_stim": 1}    {"sex\_stim": 3}      {"sex\_stim": 1}
# 4         {"sex\_stim": 1}    {"sex\_stim": 1}      {"sex\_stim": 1}
#
# [5 rows x 21 columns]

# %%
import re
def extract_sex_stim(string):
    match = re.search(r'\d+', string)
    if match:
        return int(match.group())
    else:
        return None

# %%
columns_to_update = ['low ssc characteristics', 'high ssc characteristics', 'low ssc defined', 'high ssc defined']

for column in columns_to_update:
    df[column] = df[column].apply(extract_sex_stim)

df.head()
# Out:
#       Video ID                                        Video Title  \
# 0  ATx-hlfK9o4       b'Every guys dream \xf0\x9f\x98\x82 #shorts'
# 1  tfSoHecAcqI                               b'sexy girl #shorts'
# 2  A8ZWqpTJtsk  b'Hot Dog Prank Goes Wrong! \xf0\x9f\xa4\xa3 #...
# 3  lThaG-9QRxg  b'Sex drive 8000000% - Tuesday   #wifelike #pa...
# 4  HwnXVOjLIjQ  b'\xf0\x9f\x98\x86\xf0\x9f\x91\x8f Birthday Ce...
#
#               Channel Title  \
# 0         b'Isaiah Miranda'
# 1             b'Pov Sunhai'
# 2             b'Neil Henry'
# 3  b'The.Wildwild.Universe'
# 4             b'Joytimisty'
#
#                                           Transcript  Duration  \
# 0  oh take a picture it'll last longer I wasn't l...    89.080
# 1  [Music] you can't jump out of the car right no...    32.720
# 2  foreign [Music] [Music] Jay Josh [Music] you'r...    49.207
# 3                         William sex drive [Music]     12.581
# 4                  bye [Music] [Applause] thank you     13.598
#
#    Words per Second  Number of Comments  \
# 0          2.166592               20362
# 1          0.916870                  29
# 2          0.548702                 152
# 3          0.397425                 136
# 4          0.441241                8854
#
#                                       Top10 Comments             Category  \
# 0  ['If only women were this straight up', 'Plot ...     b'Entertainment'
# 1  ['Girl she&#39;s even not wearing a shirt😂😂😂',...    b'People & Blogs'
# 2  ['Youtube then: 😜😄🤣😂<br>Youtube now:😔💀💀', 'Oh ...     b'Entertainment'
# 3  ['And people say men still treat women as obje...  b'Film & Animation'
# 4  ['ज्योती आपकी ठुकाई हो रही थी तो ऐसी हि आवाज़ आ...     b'Entertainment'
#
#        Views  ...                                       Custom Query  \
# 0  107524329  ...  You are a copywriter, create a 100 word summar...
# 1     221828  ...  You are a copywriter, create a 100 word summar...
# 2    5516390  ...  You are a copywriter, create a 100 word summar...
# 3    3186779  ...  You are a copywriter, create a 100 word summar...
# 4   50352006  ...  You are a copywriter, create a 100 word summar...
#
#                                          LLM Summary  \
# 0       Isaiah Miranda's YouTube Short "#EveryGuy...
# 1        Pov Sunhai's YouTube Short "#SexyGirl" p...
# 2        Neil Henry's YouTube Short "#HotDogPrank...
# 3         The Wildwild Universe's YouTube Short "...
# 4         JoyTimisty's YouTube Short "#BirthdayCe...
#
#                           low ssc characteristics st  \
# 0  You are a person with following characteristic...
# 1  You are a person with following characteristic...
# 2  You are a person with following characteristic...
# 3  You are a person with following characteristic...
# 4  You are a person with following characteristic...
#
#                          high ssc characteristics st  \
# 0  You are a person with following characteristic...
# 1  You are a person with following characteristic...
# 2  You are a person with following characteristic...
# 3  You are a person with following characteristic...
# 4  You are a person with following characteristic...
#
#                                   low ssc defined st  \
# 0  You are a person with low state self control a...
# 1  You are a person with low state self control a...
# 2  You are a person with low state self control a...
# 3  You are a person with low state self control a...
# 4  You are a person with low state self control a...
#
#                                  high ssc defined st low ssc characteristics  \
# 0  You are a person with high state self control ...                       2
# 1  You are a person with high state self control ...                       3
# 2  You are a person with high state self control ...                       1
# 3  You are a person with high state self control ...                       2
# 4  You are a person with high state self control ...                       1
#
#    high ssc characteristics  low ssc defined  high ssc defined
# 0                         1                3                 1
# 1                         1                4                 1
# 2                         1                1                 1
# 3                         1                3                 1
# 4                         1                1                 1
#
# [5 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with the relevant columns
columns_to_plot = ['low ssc characteristics', 'high ssc characteristics', 'low ssc defined', 'high ssc defined']

# Prepare data for the box plot
data_to_plot = [df[col].dropna() for col in columns_to_plot]

# Creating the box plot with increased figure size
fig, ax = plt.subplots(figsize=(12, 8))  # Set the size here (width, height)

# Adding patch_artist=True option to fill with color
bp = ax.boxplot(data_to_plot, patch_artist=True, notch=True, medianprops={'linewidth': 2})

# Define your colors for the boxes
#colors = ['lightblue', 'lightgreen', 'lightblue', 'lightgreen']
# Colors and labels for the legend
colors = ['lightseagreen', 'seagreen', 'palegreen', 'mediumseagreen']
labels = ['Low SSC Char.', 'High SSC Char.', 'Low SSC Def.', 'High SSC Def.']

for patch, color, label in zip(bp['boxes'], colors, labels):
    patch.set_facecolor(color)
    patch.set_label(label)

# Adding legend
ax.legend(loc='upper right')

# Adding labels
ax.set_xticklabels(['Sex_Stim \n Low SSC Char.', 'Sex_Stim \n High SSC Char.', 'Sex_Stim \n Low SSC Def.', 'Sex_Stim \n High SSC Def.'])
ax.set_ylabel('Sexual Stimulation Scores')
ax.set_title('Sexual Stimulation Distribution by Category')

plt.show()

# %% [markdown]
# Thus, if we have this weird "flipped" appearance in the notched box plots, it simply means that the 1st quartile has a lower value than the confidence of the mean and vice versa for the 3rd quartile. Although it looks ugly, it's actually useful information about the (un)confidence of the median.

# %%
import pandas as pd
df2 = pd.read_csv("csv\output\Report_Shorts_with_summary_stefan_sexist_joke_experimentResults.csv")
df2.head()
# Out:
#       Video ID                                        Video Title  \
# 0  2Qh1MJlsMrM                               b'The Best Dad Joke'
# 1  oBW8ysI5fdI  b'He asked for a second wife #fyp #viral #come...
# 2  l5vMOdIYKeg  b"Dad Jokes | Don't laugh Challenge | Abby vs ...
# 3  A30nr-_cW3w  b"Emily Blunt's Impression Is *Chefs Kiss* #Sh...
# 4  Ch-hwFB_ix8  b'When the lights went off\xf0\x9f\x98\x82. Fu...
#
#                  Channel Title  \
# 0                   b'LPMedia'
# 1              b'The Gabriels'
# 2                   b'YeahMad'
# 3    b'The Graham Norton Show'
# 4  b'Daily dose of family guy'
#
#                                           Transcript  Duration  \
# 0  my wife told me to be more in touch with my fe...    19.019
# 1  would you care if we got a second wife second ...    66.900
# 2  this might be the end of our friendship [Music...  1460.462
# 3  you grew that human and little human popped ou...    68.798
# 4  lois over here honey i'm chopping carrots for ...   105.280
#
#    Words per Second  Number of Comments  \
# 0          1.472212                4675
# 1          1.315396               10082
# 2          1.181818                5306
# 3          1.526207                2736
# 4          1.472264                2499
#
#                                       Top10 Comments           Category  \
# 0  ['My wife said “can’t you treat me like before...  b'People & Blogs'
# 1  ['&quot;I don&#39;t share my nuts&quot; 🤣🤣🤣', ...  b'People & Blogs'
# 2  ['Some of the best jokes I&#39;ve heard in a w...          b'Comedy'
# 3  ['Thats an old black lady for keeping it real....   b'Entertainment'
# 4  ['The joke I thought was that brian was actual...          b'Comedy'
#
#       Views  ...                                       Custom Query  \
# 0   7222817  ...  You are a copywriter, create a 100 word summar...
# 1   8620555  ...  You are a copywriter, create a 100 word summar...
# 2   3738422  ...  You are a copywriter, create a 100 word summar...
# 3  16097254  ...  You are a copywriter, create a 100 word summar...
# 4  23978767  ...  You are a copywriter, create a 100 word summar...
#
#                                          LLM Summary  \
# 0                               LPMedia's YouTube...
# 1                               The Gabriels' You...
# 2                               YeahMad's YouTube...
# 3                             The Graham Norton S...
# 4                               Daily Dose Of Fam...
#
#                           low ssc characteristics st  \
# 0  You are a person with following characteristic...
# 1  You are a person with following characteristic...
# 2  You are a person with following characteristic...
# 3  You are a person with following characteristic...
# 4  You are a person with following characteristic...
#
#                          high ssc characteristics st  \
# 0  You are a person with following characteristic...
# 1  You are a person with following characteristic...
# 2  You are a person with following characteristic...
# 3  You are a person with following characteristic...
# 4  You are a person with following characteristic...
#
#                                   low ssc defined st  \
# 0  You are a person with low state self control a...
# 1  You are a person with low state self control a...
# 2  You are a person with low state self control a...
# 3  You are a person with low state self control a...
# 4  You are a person with low state self control a...
#
#                                  high ssc defined st  \
# 0  You are a person with high state self control ...
# 1  You are a person with high state self control ...
# 2  You are a person with high state self control ...
# 3  You are a person with high state self control ...
# 4  You are a person with high state self control ...
#
#                     low ssc characteristics  \
# 0   {\n"enjoyment": 3,\n"appropriate": 4\n}
# 1        {"enjoyment": 4, "appropriate": 3}
# 2        {"enjoyment": 4, "appropriate": 2}
# 3        {"enjoyment": 4, "appropriate": 3}
# 4   {\n"enjoyment": 4,\n"appropriate": 3\n}
#
#                     high ssc characteristics  \
# 0    {\n"enjoyment": 2,\n"appropriate": 3\n}
# 1         {"enjoyment": 3, "appropriate": 4}
# 2         {"enjoyment": 3, "appropriate": 3}
# 3         {"enjoyment": 3, "appropriate": 4}
# 4    {\n"enjoyment": 3,\n"appropriate": 4\n}
#
#                                 low ssc defined  \
# 0       {\n"enjoyment": 4,\n"appropriate": 2\n}
# 1            {"enjoyment": 4, "appropriate": 2}
# 2            {"enjoyment": 4, "appropriate": 2}
# 3            {"enjoyment": 4, "appropriate": 3}
# 4       {\n"enjoyment": 4,\n"appropriate": 2\n}
#
#                                 high ssc defined
# 0        {\n"enjoyment": 3,\n"appropriate": 4\n}
# 1             {"enjoyment": 3, "appropriate": 4}
# 2             {"enjoyment": 3, "appropriate": 3}
# 3             {"enjoyment": 3, "appropriate": 4}
# 4        {\n"enjoyment": 3,\n"appropriate": 4\n}
#
# [5 rows x 21 columns]

# %%
import pandas as pd
import json

# Define the columns to update
columns_to_update = ['low ssc characteristics', 'high ssc characteristics', 'low ssc defined', 'high ssc defined']

# For each column, clean the strings, parse them into dictionaries, and extract the "enjoyment" and "appropriate" values
for column in columns_to_update:
    df2[column] = df2[column].str.replace('\n', '').apply(json.loads)
    df2[[f'{column}_enjoyment', f'{column}_appropriate']] = df2[column].apply(pd.Series)

# %%
df2.head()
# Out:
#       Video ID                                        Video Title  \
# 0  2Qh1MJlsMrM                               b'The Best Dad Joke'
# 1  oBW8ysI5fdI  b'He asked for a second wife #fyp #viral #come...
# 2  l5vMOdIYKeg  b"Dad Jokes | Don't laugh Challenge | Abby vs ...
# 3  A30nr-_cW3w  b"Emily Blunt's Impression Is *Chefs Kiss* #Sh...
# 4  Ch-hwFB_ix8  b'When the lights went off\xf0\x9f\x98\x82. Fu...
#
#                  Channel Title  \
# 0                   b'LPMedia'
# 1              b'The Gabriels'
# 2                   b'YeahMad'
# 3    b'The Graham Norton Show'
# 4  b'Daily dose of family guy'
#
#                                           Transcript  Duration  \
# 0  my wife told me to be more in touch with my fe...    19.019
# 1  would you care if we got a second wife second ...    66.900
# 2  this might be the end of our friendship [Music...  1460.462
# 3  you grew that human and little human popped ou...    68.798
# 4  lois over here honey i'm chopping carrots for ...   105.280
#
#    Words per Second  Number of Comments  \
# 0          1.472212                4675
# 1          1.315396               10082
# 2          1.181818                5306
# 3          1.526207                2736
# 4          1.472264                2499
#
#                                       Top10 Comments           Category  \
# 0  ['My wife said “can’t you treat me like before...  b'People & Blogs'
# 1  ['&quot;I don&#39;t share my nuts&quot; 🤣🤣🤣', ...  b'People & Blogs'
# 2  ['Some of the best jokes I&#39;ve heard in a w...          b'Comedy'
# 3  ['Thats an old black lady for keeping it real....   b'Entertainment'
# 4  ['The joke I thought was that brian was actual...          b'Comedy'
#
#       Views  ...                     low ssc defined  \
# 0   7222817  ...  {'enjoyment': 4, 'appropriate': 2}
# 1   8620555  ...  {'enjoyment': 4, 'appropriate': 2}
# 2   3738422  ...  {'enjoyment': 4, 'appropriate': 2}
# 3  16097254  ...  {'enjoyment': 4, 'appropriate': 3}
# 4  23978767  ...  {'enjoyment': 4, 'appropriate': 2}
#
#                      high ssc defined low ssc characteristics_enjoyment  \
# 0  {'enjoyment': 3, 'appropriate': 4}                                 3
# 1  {'enjoyment': 3, 'appropriate': 4}                                 4
# 2  {'enjoyment': 3, 'appropriate': 3}                                 4
# 3  {'enjoyment': 3, 'appropriate': 4}                                 4
# 4  {'enjoyment': 3, 'appropriate': 4}                                 4
#
#   low ssc characteristics_appropriate high ssc characteristics_enjoyment  \
# 0                                   4                                  2
# 1                                   3                                  3
# 2                                   2                                  3
# 3                                   3                                  3
# 4                                   3                                  3
#
#   high ssc characteristics_appropriate low ssc defined_enjoyment  \
# 0                                    3                         4
# 1                                    4                         4
# 2                                    3                         4
# 3                                    4                         4
# 4                                    4                         4
#
#   low ssc defined_appropriate high ssc defined_enjoyment  \
# 0                           2                          3
# 1                           2                          3
# 2                           2                          3
# 3                           3                          3
# 4                           2                          3
#
#   high ssc defined_appropriate
# 0                            4
# 1                            4
# 2                            3
# 3                            4
# 4                            4
#
# [5 rows x 29 columns]

# %%
import matplotlib.pyplot as plt

# Define the columns to plot
columns_to_plot = [f'{column}_enjoyment' for column in columns_to_update] + [f'{column}_appropriate' for column in columns_to_update]

# Prepare data for the box plot
data_to_plot = [df2[col].dropna() for col in columns_to_plot]

# Creating the box plot with increased figure size
fig, ax = plt.subplots(figsize=(12, 8))  # Set the size here (width, height)

# Adding patch_artist=True option to fill with color
bp = ax.boxplot(data_to_plot, patch_artist=True, notch=True, medianprops={'linewidth': 2})

# Define your colors for the boxes
colors = ['lightseagreen', 'seagreen', 'palegreen', 'mediumseagreen'] * 2  # Repeat the colors for the '_appropriate' columns

# Define labels for the boxes in the order of the DataFrame columns
labels = ['Low SSC Char. Enjoym.', 'Low SSC Char. Appr.', 'High SSC Char. Enjoym.', 'High SSC Char. Appr.', 
          'Low SSC Def. Enjoym.', 'Low SSC Def. Appr.', 'High SSC Def. Enjoym.', 'High SSC Def. Appr.']

# Adding labels
for patch, color, label in zip(bp['boxes'], colors, labels):
    patch.set_facecolor(color)
    patch.set_label(label)

# Adding labels
ax.set_xticklabels(labels, rotation=45)  # Rotate the labels 45 degrees for better visibility
ax.set_ylabel('Values')
ax.set_title('Enjoyment / Appropriate Scores by Category')

plt.show()

# %%
df = pd.read_csv("csv\output\Report_Shorts_with_summary_stefan_sexist_joke_experimentResults.csv")
df.head(20)
# Out:
#        Video ID                                        Video Title  \
# 0   2Qh1MJlsMrM                               b'The Best Dad Joke'
# 1   oBW8ysI5fdI  b'He asked for a second wife #fyp #viral #come...
# 2   l5vMOdIYKeg  b"Dad Jokes | Don't laugh Challenge | Abby vs ...
# 3   A30nr-_cW3w  b"Emily Blunt's Impression Is *Chefs Kiss* #Sh...
# 4   Ch-hwFB_ix8  b'When the lights went off\xf0\x9f\x98\x82. Fu...
# 5   ehyriQDWv4s  b'Urinals are SEXIST?!?! #lol #short #basketof...
# 6   8lOClOhD6Ys  b'Women are SEXIST but smart \xf0\x9f\x98\x82|...
# 7   YzFSkWozYDY  b'Margot Robbie PUNCHED an actor on the Barbie...
# 8   -JY_5r4WURI  b'sexiest yellow characters this one\xe2\x80\x...
# 9   psNBxXWDclM                       b'Dark humor jokes part #83'
# 10  0acRhxIkEyU  b'Scarlett shuts down sexist question. #shorts...
# 11  j18SwdutMVo  b'My Girlfriend want a Baby \xf0\x9f\x91\xb6\x...
# 12  xy8eeohKY9I  b'Super Model Gisele Bundchen vs. Jimmy Fallon...
# 13  PwwdZ-ldYDo  b'Joe Rogan | If Harvey Weinstein Was A Women ...
# 14  cam1Ge4HXNs  b'Sexist magician\xf0\x9f\x98\xb1\xf0\x9f\x98\...
#
#                   Channel Title  \
# 0                    b'LPMedia'
# 1               b'The Gabriels'
# 2                    b'YeahMad'
# 3     b'The Graham Norton Show'
# 4   b'Daily dose of family guy'
# 5             b'Basket of Cats'
# 6                 b'Bozz Clips'
# 7                  b'TheThings'
# 8               b'Liv Pearsall'
# 9          b'TheBroCodeNetwork'
# 10                b'Zen Lethal'
# 11             b'NickandCarrie'
# 12             b'Riches Shorts'
# 13             b'Comedy Corner'
# 14             b'MAGICAL WORLD'
#
#                                            Transcript  Duration  \
# 0   my wife told me to be more in touch with my fe...    19.019
# 1   would you care if we got a second wife second ...    66.900
# 2   this might be the end of our friendship [Music...  1460.462
# 3   you grew that human and little human popped ou...    68.798
# 4   lois over here honey i'm chopping carrots for ...   105.280
# 5   I brought the fact that I think that urinals a...    78.481
# 6   a woman can say something like yeah that guy w...    82.338
# 7   who knew barbie had a mean right hook margot r...    43.678
# 8   I'm glad you all are rocking with these becaus...   105.100
# 9   what do you call a flat suicidal girl a cuttin...    37.600
# 10  people to wear undergarments if you're like th...   107.241
# 11  [Music] baby didn't you had ice cream after di...    36.240
# 12  so go like this put your thing is showing over...   107.588
# 13  if Harvey Weinstein was a woman who looked lik...   104.730
# 14  with the different underwears okay thank you s...    97.410
#
#     Words per Second  Number of Comments  \
# 0           1.472212                4675
# 1           1.315396               10082
# 2           1.181818                5306
# 3           1.526207                2736
# 4           1.472264                2499
# 5           1.669194                   1
# 6           1.955355                   1
# 7           1.465269                9319
# 8           1.798287                7354
# 9           1.276596                 236
# 10          1.529266                   0
# 11          0.965784                5153
# 12          1.431386                2760
# 13          1.422706                1859
# 14          0.615953                   0
#
#                                        Top10 Comments           Category  \
# 0   ['My wife said “can’t you treat me like before...  b'People & Blogs'
# 1   ['&quot;I don&#39;t share my nuts&quot; 🤣🤣🤣', ...  b'People & Blogs'
# 2   ['Some of the best jokes I&#39;ve heard in a w...          b'Comedy'
# 3   ['Thats an old black lady for keeping it real....   b'Entertainment'
# 4   ['The joke I thought was that brian was actual...          b'Comedy'
# 5                           ['save my urinals 💕💕💕💕💕']  b'People & Blogs'
# 6                             ['Fuckin right lmaooo']          b'Comedy'
# 7   ['I mean she Harley Quinn After all', '&quot;S...   b'Entertainment'
# 8   ['You forgot Barry from the bee movie 😂 I don’...  b'People & Blogs'
# 9   ['Bro used the dark side of the force for that...   b'Entertainment'
# 10                                                 []       b'Education'
# 11  ['they need to get married<br><br><br>👇', 'Peo...  b'People & Blogs'
# 12  ['“my wife is gonna kill me, i-i-i-im not-“💀💀'...  b'People & Blogs'
# 13  ['Duuude... You&#39;re gonna be batman 🤣', 'A ...          b'Comedy'
# 14                                                 []   b'Entertainment'
#
#        Views  ...                                       Custom Query  \
# 0    7222817  ...  You are a copywriter, create a 100 word summar...
# 1    8620555  ...  You are a copywriter, create a 100 word summar...
# 2    3738422  ...  You are a copywriter, create a 100 word summar...
# 3   16097254  ...  You are a copywriter, create a 100 word summar...
# 4   23978767  ...  You are a copywriter, create a 100 word summar...
# 5       1502  ...  You are a copywriter, create a 100 word summar...
# 6         55  ...  You are a copywriter, create a 100 word summar...
# 7   35842446  ...  You are a copywriter, create a 100 word summar...
# 8    2668429  ...  You are a copywriter, create a 100 word summar...
# 9     779073  ...  You are a copywriter, create a 100 word summar...
# 10      1144  ...  You are a copywriter, create a 100 word summar...
# 11  15110838  ...  You are a copywriter, create a 100 word summar...
# 12  61057541  ...  You are a copywriter, create a 100 word summar...
# 13   2898255  ...  You are a copywriter, create a 100 word summar...
# 14     26367  ...  You are a copywriter, create a 100 word summar...
#
#                                           LLM Summary  \
# 0                                LPMedia's YouTube...
# 1                                The Gabriels' You...
# 2                                YeahMad's YouTube...
# 3                              The Graham Norton S...
# 4                                Daily Dose Of Fam...
# 5                                Basket of Cats' Y...
# 6                                Bozz Clips' YouTu...
# 7                                  TheThings' YouT...
# 8                                Liv Pearsall's Yo...
# 9                                TheBroCodeNetwork...
# 10                               Zen Lethal's YouT...
# 11                               NickandCarrie's Y...
# 12                                Riches Shorts' Y...
# 13                               Comedy Corner's Y...
# 14                               Magical World's Y...
#
#                            low ssc characteristics st  \
# 0   You are a person with following characteristic...
# 1   You are a person with following characteristic...
# 2   You are a person with following characteristic...
# 3   You are a person with following characteristic...
# 4   You are a person with following characteristic...
# 5   You are a person with following characteristic...
# 6   You are a person with following characteristic...
# 7   You are a person with following characteristic...
# 8   You are a person with following characteristic...
# 9   You are a person with following characteristic...
# 10  You are a person with following characteristic...
# 11  You are a person with following characteristic...
# 12  You are a person with following characteristic...
# 13  You are a person with following characteristic...
# 14  You are a person with following characteristic...
#
#                           high ssc characteristics st  \
# 0   You are a person with following characteristic...
# 1   You are a person with following characteristic...
# 2   You are a person with following characteristic...
# 3   You are a person with following characteristic...
# 4   You are a person with following characteristic...
# 5   You are a person with following characteristic...
# 6   You are a person with following characteristic...
# 7   You are a person with following characteristic...
# 8   You are a person with following characteristic...
# 9   You are a person with following characteristic...
# 10  You are a person with following characteristic...
# 11  You are a person with following characteristic...
# 12  You are a person with following characteristic...
# 13  You are a person with following characteristic...
# 14  You are a person with following characteristic...
#
#                                    low ssc defined st  \
# 0   You are a person with low state self control a...
# 1   You are a person with low state self control a...
# 2   You are a person with low state self control a...
# 3   You are a person with low state self control a...
# 4   You are a person with low state self control a...
# 5   You are a person with low state self control a...
# 6   You are a person with low state self control a...
# 7   You are a person with low state self control a...
# 8   You are a person with low state self control a...
# 9   You are a person with low state self control a...
# 10  You are a person with low state self control a...
# 11  You are a person with low state self control a...
# 12  You are a person with low state self control a...
# 13  You are a person with low state self control a...
# 14  You are a person with low state self control a...
#
#                                   high ssc defined st  \
# 0   You are a person with high state self control ...
# 1   You are a person with high state self control ...
# 2   You are a person with high state self control ...
# 3   You are a person with high state self control ...
# 4   You are a person with high state self control ...
# 5   You are a person with high state self control ...
# 6   You are a person with high state self control ...
# 7   You are a person with high state self control ...
# 8   You are a person with high state self control ...
# 9   You are a person with high state self control ...
# 10  You are a person with high state self control ...
# 11  You are a person with high state self control ...
# 12  You are a person with high state self control ...
# 13  You are a person with high state self control ...
# 14  You are a person with high state self control ...
#
#                      low ssc characteristics  \
# 0    {\n"enjoyment": 3,\n"appropriate": 4\n}
# 1         {"enjoyment": 4, "appropriate": 3}
# 2         {"enjoyment": 4, "appropriate": 2}
# 3         {"enjoyment": 4, "appropriate": 3}
# 4    {\n"enjoyment": 4,\n"appropriate": 3\n}
# 5    {\n"enjoyment": 3,\n"appropriate": 4\n}
# 6    {\n"enjoyment": 4,\n"appropriate": 3\n}
# 7    {\n"enjoyment": 4,\n"appropriate": 5\n}
# 8    {\n"enjoyment": 4,\n"appropriate": 3\n}
# 9    {\n"enjoyment": 4,\n"appropriate": 2\n}
# 10   {\n"enjoyment": 3,\n"appropriate": 5\n}
# 11        {"enjoyment": 4, "appropriate": 3}
# 12        {"enjoyment": 4, "appropriate": 5}
# 13   {\n"enjoyment": 3,\n"appropriate": 2\n}
# 14        {"enjoyment": 4, "appropriate": 2}
#
#                      high ssc characteristics  \
# 0     {\n"enjoyment": 2,\n"appropriate": 3\n}
# 1          {"enjoyment": 3, "appropriate": 4}
# 2          {"enjoyment": 3, "appropriate": 3}
# 3          {"enjoyment": 3, "appropriate": 4}
# 4     {\n"enjoyment": 3,\n"appropriate": 4\n}
# 5     {\n"enjoyment": 2,\n"appropriate": 3\n}
# 6     {\n"enjoyment": 3,\n"appropriate": 4\n}
# 7     {\n"enjoyment": 3,\n"appropriate": 5\n}
# 8     {\n"enjoyment": 3,\n"appropriate": 4\n}
# 9     {\n"enjoyment": 3,\n"appropriate": 3\n}
# 10    {\n"enjoyment": 4,\n"appropriate": 5\n}
# 11         {"enjoyment": 3, "appropriate": 4}
# 12         {"enjoyment": 3, "appropriate": 5}
# 13    {\n"enjoyment": 2,\n"appropriate": 3\n}
# 14         {"enjoyment": 3, "appropriate": 3}
#
#                                  low ssc defined  \
# 0        {\n"enjoyment": 4,\n"appropriate": 2\n}
# 1             {"enjoyment": 4, "appropriate": 2}
# 2             {"enjoyment": 4, "appropriate": 2}
# 3             {"enjoyment": 4, "appropriate": 3}
# 4        {\n"enjoyment": 4,\n"appropriate": 2\n}
# 5        {\n"enjoyment": 4,\n"appropriate": 2\n}
# 6        {\n"enjoyment": 4,\n"appropriate": 2\n}
# 7        {\n"enjoyment": 4,\n"appropriate": 4\n}
# 8        {\n"enjoyment": 4,\n"appropriate": 2\n}
# 9        {\n"enjoyment": 4,\n"appropriate": 2\n}
# 10       {\n"enjoyment": 2,\n"appropriate": 4\n}
# 11            {"enjoyment": 4, "appropriate": 2}
# 12            {"enjoyment": 4, "appropriate": 4}
# 13       {\n"enjoyment": 4,\n"appropriate": 1\n}
# 14            {"enjoyment": 4, "appropriate": 2}
#
#                                  high ssc defined
# 0         {\n"enjoyment": 3,\n"appropriate": 4\n}
# 1              {"enjoyment": 3, "appropriate": 4}
# 2              {"enjoyment": 3, "appropriate": 3}
# 3              {"enjoyment": 3, "appropriate": 4}
# 4         {\n"enjoyment": 3,\n"appropriate": 4\n}
# 5         {\n"enjoyment": 3,\n"appropriate": 4\n}
# 6         {\n"enjoyment": 3,\n"appropriate": 4\n}
# 7         {\n"enjoyment": 3,\n"appropriate": 5\n}
# 8         {\n"enjoyment": 3,\n"appropriate": 4\n}
# 9         {\n"enjoyment": 3,\n"appropriate": 3\n}
# 10        {\n"enjoyment": 4,\n"appropriate": 5\n}
# 11             {"enjoyment": 3, "appropriate": 4}
# 12             {"enjoyment": 3, "appropriate": 5}
# 13        {\n"enjoyment": 3,\n"appropriate": 3\n}
# 14             {"enjoyment": 3, "appropriate": 2}
#
# [15 rows x 21 columns]

# %%
df = pd.read_csv("csv\output\Report_Shorts_with_summary_stefan_sexy_experimentResults.csv")

len(df)
# Out:
# 47

# %%
df = pd.read_csv("csv\output\Report_Shorts_with_summary_stefan_sexist_joke.csv")
len(df)
# Out:
# 85
