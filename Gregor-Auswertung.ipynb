# %%
import pandas as pd
import json
import re
import matplotlib.pyplot as plt
import numpy as np

RESULTS_FUNNY = "csv/output/Report_Shorts_with_summary_gregor_funny_experiment_results_cleaned.csv"

df_shorts = pd.read_csv(RESULTS_FUNNY, sep=",")

results = {}
results['low_ssc_characteristics'] = []
results['high_ssc_characteristics'] = []
results['low_ssc_defined'] = []
results['high_ssc_defined'] = []

total_laugh_low_ssc_characteristics = 0
total_smile_low_ssc_characteristics = 0
total_amusement_low_ssc_characteristics = 0

total_laugh_high_ssc_characteristics = 0
total_smile_high_ssc_characteristics = 0
total_amusement_high_ssc_characteristics = 0

total_laugh_low_ssc_defined = 0
total_smile_low_ssc_defined = 0
total_amusement_low_ssc_defined = 0

total_laugh_high_ssc_defined = 0
total_smile_high_ssc_defined = 0
total_amusement_high_ssc_defined = 0

for index, row in df_shorts.iterrows():
    results['low_ssc_characteristics'].append(json.loads(row['low ssc characteristics']))
    results['high_ssc_characteristics'].append(json.loads(row['high ssc characteristics']))
    results['low_ssc_defined'].append(json.loads(row['low ssc defined']))
    results['high_ssc_defined'].append(json.loads(row['high ssc defined']))

for i in range(0,len(results['low_ssc_characteristics'])):
    total_laugh_low_ssc_characteristics += results['low_ssc_characteristics'][i]["smiles"]
    total_smile_low_ssc_characteristics += results['low_ssc_characteristics'][i]["laughs"]
    total_amusement_low_ssc_characteristics += results['low_ssc_characteristics'][i]["amusement_rating"]
    
    total_laugh_high_ssc_characteristics += results['high_ssc_characteristics'][i]["smiles"]
    total_smile_high_ssc_characteristics += results['high_ssc_characteristics'][i]["laughs"]
    total_amusement_high_ssc_characteristics += results['high_ssc_characteristics'][i]["amusement_rating"]
    
    total_laugh_low_ssc_defined += results['low_ssc_defined'][i]["smiles"]
    total_smile_low_ssc_defined += results['low_ssc_defined'][i]["laughs"]
    total_amusement_low_ssc_defined += results['low_ssc_defined'][i]["amusement_rating"]
    
    total_laugh_high_ssc_defined += results['high_ssc_defined'][i]["smiles"]
    total_smile_high_ssc_defined += results['high_ssc_defined'][i]["laughs"]
    total_amusement_high_ssc_defined += results['high_ssc_defined'][i]["amusement_rating"]

avg_laugh_low_ssc_characteristics = total_laugh_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_smile_low_ssc_characteristics = total_smile_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_amusement_low_ssc_characteristics = total_amusement_low_ssc_characteristics/len(results['low_ssc_characteristics'])

avg_laugh_high_ssc_characteristics = total_laugh_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_smile_high_ssc_characteristics = total_smile_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_amusement_high_ssc_characteristics = total_amusement_high_ssc_characteristics/len(results['low_ssc_characteristics'])

avg_laugh_low_ssc_defined = total_laugh_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_smile_low_ssc_defined = total_smile_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_amusement_low_ssc_defined = total_amusement_low_ssc_defined/len(results['low_ssc_characteristics'])

avg_laugh_high_ssc_defined = total_laugh_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_smile_high_ssc_defined = total_smile_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_amusement_high_ssc_defined = total_amusement_high_ssc_defined/len(results['low_ssc_characteristics'])

plt.rcParams.update({'font.size': 7})

x = np.arange(3)
y1 = [avg_amusement_high_ssc_characteristics, avg_laugh_high_ssc_characteristics, avg_smile_high_ssc_characteristics]
y2 = [avg_amusement_low_ssc_characteristics, avg_laugh_low_ssc_characteristics, avg_smile_low_ssc_characteristics]
width = 0.2

plt.bar(x-0.1,y1, width, color='lightseagreen')
plt.bar(x+0.1,y2, width, color='seagreen')
plt.xticks(x, ['Avg. Amusement', 'Avg. Laughs', 'Avg. Smiles'])
plt.legend(["High SSC", "Low SSC "])
plt.savefig('funny_ssc_characteristics.png', dpi=1000)
plt.show()

x = np.arange(3)
y1 = [avg_amusement_high_ssc_defined, avg_laugh_high_ssc_defined, avg_smile_high_ssc_defined]
y2 = [avg_amusement_low_ssc_defined, avg_laugh_low_ssc_defined, avg_smile_low_ssc_defined]
width = 0.2

plt.bar(x-0.1,y1, width, color='lightseagreen')
plt.bar(x+0.1,y2, width, color='seagreen')
plt.xticks(x, ['Avg. Amusement', 'Avg. Laughs', 'Avg. Smiles'])
plt.legend(["High SSC", "Low SSC "]) 
plt.savefig('funny_ssc_defined.png', dpi=1000)
plt.show()

print("SSC Characteristics High")
print(avg_amusement_high_ssc_characteristics)
print(avg_laugh_high_ssc_characteristics)
print(avg_smile_high_ssc_characteristics)

print("SSC Characteristics Low")
print(avg_amusement_low_ssc_characteristics)
print(avg_laugh_low_ssc_characteristics)
print(avg_smile_low_ssc_characteristics)

print("SSC Defined High")
print(avg_amusement_high_ssc_defined)
print(avg_laugh_high_ssc_defined)
print(avg_smile_high_ssc_defined)

print("SSC Defined Low")
print(avg_amusement_low_ssc_defined)
print(avg_laugh_low_ssc_defined)
print(avg_smile_low_ssc_defined)
# Out:
# SSC Characteristics High
# 2.2247191011235956
# 2.101123595505618
# 0.7865168539325843
# SSC Characteristics Low
# 3.1123595505617976
# 3.1797752808988764
# 1.9438202247191012
# SSC Defined High
# 2.134831460674157
# 1.9887640449438202
# 0.6292134831460674
# SSC Defined Low
# 2.067415730337079
# 2.3820224719101124
# 0.7528089887640449

# %%
RESULTS_GRUESOME = "csv/output/Report_Shorts_with_summary_gregor_gruesome_experiment_results_cleaned.csv"

df_shorts = pd.read_csv(RESULTS_GRUESOME, sep=",")

results = {}
results['low_ssc_characteristics'] = []
results['high_ssc_characteristics'] = []
results['low_ssc_defined'] = []
results['high_ssc_defined'] = []

total_depressed_low_ssc_characteristics = 0
total_tense_low_ssc_characteristics = 0
total_sorry_low_ssc_characteristics = 0
total_dissatisfied_low_ssc_characteristics = 0
total_anxious_low_ssc_characteristics = 0
total_emotion_visibility_low_ssc_characteristics = 0

total_depressed_high_ssc_characteristics = 0
total_tense_high_ssc_characteristics = 0
total_sorry_high_ssc_characteristics = 0
total_dissatisfied_high_ssc_characteristics = 0
total_anxious_high_ssc_characteristics = 0
total_emotion_visibility_high_ssc_characteristics = 0

total_depressed_low_ssc_defined = 0
total_tense_low_ssc_defined = 0
total_sorry_low_ssc_defined = 0
total_dissatisfied_low_ssc_defined = 0
total_anxious_low_ssc_defined = 0
total_emotion_visibility_low_ssc_defined = 0

total_depressed_high_ssc_defined = 0
total_tense_high_ssc_defined = 0
total_sorry_high_ssc_defined = 0
total_dissatisfied_high_ssc_defined = 0
total_anxious_high_ssc_defined = 0
total_emotion_visibility_high_ssc_defined = 0

for index, row in df_shorts.iterrows():
    results['low_ssc_characteristics'].append(json.loads(row['low ssc characteristics']))
    results['high_ssc_characteristics'].append(json.loads(row['high ssc characteristics']))
    results['low_ssc_defined'].append(json.loads(row['low ssc defined']))
    results['high_ssc_defined'].append(json.loads(row['high ssc defined']))

for i in range(0,len(results['low_ssc_characteristics'])):
    total_depressed_low_ssc_characteristics += results['low_ssc_characteristics'][i]["depressed"]
    total_tense_low_ssc_characteristics += results['low_ssc_characteristics'][i]["tense"]
    total_sorry_low_ssc_characteristics += results['low_ssc_characteristics'][i]["sorry"]
    total_dissatisfied_low_ssc_characteristics += results['low_ssc_characteristics'][i]["dissatisfied"]
    total_anxious_low_ssc_characteristics += results['low_ssc_characteristics'][i]["anxious"]
    total_emotion_visibility_low_ssc_characteristics += results['low_ssc_characteristics'][i]["emotion_visibility"]

    total_depressed_high_ssc_characteristics += results['high_ssc_characteristics'][i]["depressed"]
    total_tense_high_ssc_characteristics += results['high_ssc_characteristics'][i]["tense"]
    total_sorry_high_ssc_characteristics += results['high_ssc_characteristics'][i]["sorry"]
    total_dissatisfied_high_ssc_characteristics += results['high_ssc_characteristics'][i]["dissatisfied"]
    total_anxious_high_ssc_characteristics += results['high_ssc_characteristics'][i]["anxious"]
    total_emotion_visibility_high_ssc_characteristics += results['high_ssc_characteristics'][i]["emotion_visibility"]

    total_depressed_low_ssc_defined += results['low_ssc_defined'][i]["depressed"]
    total_tense_low_ssc_defined += results['low_ssc_defined'][i]["tense"]
    total_sorry_low_ssc_defined += results['low_ssc_defined'][i]["sorry"]
    total_dissatisfied_low_ssc_defined += results['low_ssc_defined'][i]["dissatisfied"]
    total_anxious_low_ssc_defined += results['low_ssc_defined'][i]["anxious"]
    total_emotion_visibility_low_ssc_defined += results['low_ssc_defined'][i]["emotion_visibility"]

    total_depressed_high_ssc_defined += results['high_ssc_defined'][i]["depressed"]
    total_tense_high_ssc_defined += results['high_ssc_defined'][i]["tense"]
    total_sorry_high_ssc_defined += results['high_ssc_defined'][i]["sorry"]
    total_dissatisfied_high_ssc_defined += results['high_ssc_defined'][i]["dissatisfied"]
    total_anxious_high_ssc_defined += results['high_ssc_defined'][i]["anxious"]
    total_emotion_visibility_high_ssc_defined += results['high_ssc_defined'][i]["emotion_visibility"]

avg_depressed_low_ssc_characteristics = total_depressed_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_tense_low_ssc_characteristics = total_tense_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_sorry_low_ssc_characteristics = total_sorry_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_dissatisfied_low_ssc_characteristics = total_dissatisfied_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_anxious_low_ssc_characteristics = total_anxious_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_emotion_visibility_low_ssc_characteristics = total_emotion_visibility_low_ssc_characteristics/len(results['low_ssc_characteristics'])

avg_depressed_high_ssc_characteristics = total_depressed_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_tense_high_ssc_characteristics = total_tense_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_sorry_high_ssc_characteristics = total_sorry_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_dissatisfied_high_ssc_characteristics = total_dissatisfied_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_anxious_high_ssc_characteristics = total_anxious_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_emotion_visibility_high_ssc_characteristics = total_emotion_visibility_high_ssc_characteristics/len(results['low_ssc_characteristics'])

avg_depressed_low_ssc_defined = total_depressed_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_tense_low_ssc_defined = total_tense_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_sorry_low_ssc_defined = total_sorry_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_dissatisfied_low_ssc_defined = total_dissatisfied_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_anxious_low_ssc_defined = total_anxious_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_emotion_visibility_low_ssc_defined = total_emotion_visibility_low_ssc_defined/len(results['low_ssc_characteristics'])

avg_depressed_high_ssc_defined = total_depressed_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_tense_high_ssc_defined = total_tense_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_sorry_high_ssc_defined = total_sorry_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_dissatisfied_high_ssc_defined = total_dissatisfied_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_anxious_high_ssc_defined = total_anxious_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_emotion_visibility_high_ssc_defined = total_emotion_visibility_high_ssc_defined/len(results['low_ssc_characteristics'])

plt.rcParams.update({'font.size': 7})

x = np.arange(6)
y1 = [avg_depressed_high_ssc_characteristics, avg_tense_high_ssc_characteristics,
     avg_dissatisfied_high_ssc_characteristics, avg_anxious_high_ssc_characteristics, avg_sorry_high_ssc_characteristics, avg_emotion_visibility_high_ssc_characteristics]
y2 = [avg_depressed_low_ssc_characteristics, avg_tense_low_ssc_characteristics,
     avg_dissatisfied_low_ssc_characteristics, avg_anxious_low_ssc_characteristics, avg_sorry_low_ssc_characteristics, avg_emotion_visibility_low_ssc_characteristics]
width = 0.2

plt.bar(x-0.1,y1, width, color='lightseagreen')
plt.bar(x+0.1,y2, width, color='seagreen')
plt.xticks(x, ['Depressed', 'Tense', 'Dissatisfied', 'Anxious', 'Sorry', 'Emotions Visible'])
plt.legend(["High SSC", "Low SSC "]) 
plt.savefig('gruesome_ssc_characteristics.png', dpi=1000)
plt.show()

x = np.arange(6)
y1 = [avg_depressed_high_ssc_defined, avg_tense_high_ssc_defined,
     avg_dissatisfied_high_ssc_defined, avg_anxious_high_ssc_defined, avg_sorry_high_ssc_defined, avg_emotion_visibility_high_ssc_defined]
y2 = [avg_depressed_low_ssc_defined, avg_tense_low_ssc_defined,
     avg_dissatisfied_low_ssc_defined, avg_anxious_low_ssc_defined, avg_sorry_low_ssc_defined, avg_emotion_visibility_low_ssc_defined]
width = 0.2

plt.bar(x-0.1,y1, width, color='lightseagreen')
plt.bar(x+0.1,y2, width, color='seagreen')
plt.xticks(x, ['Depressed', 'Tense', 'Dissatisfied', 'Anxious', 'Sorry', 'Emotions Visible'])
plt.legend(["High SSC", "Low SSC "]) 
plt.savefig('gruesome_ssc_defined.png', dpi=1000)
plt.show()

print("High Characteristics")
print(avg_depressed_high_ssc_characteristics)
print(avg_tense_high_ssc_characteristics)
print(avg_dissatisfied_high_ssc_characteristics)
print(avg_anxious_high_ssc_characteristics)
print(avg_sorry_high_ssc_characteristics)
print(avg_emotion_visibility_high_ssc_characteristics)

print("Low Characteristics")
print(avg_depressed_low_ssc_characteristics)
print(avg_tense_low_ssc_characteristics)
print(avg_dissatisfied_low_ssc_characteristics)
print(avg_anxious_low_ssc_characteristics)
print(avg_sorry_low_ssc_characteristics)
print(avg_emotion_visibility_low_ssc_characteristics)

print("High Defined")
print(avg_depressed_high_ssc_defined)
print(avg_tense_high_ssc_defined)
print(avg_dissatisfied_high_ssc_defined)
print(avg_anxious_high_ssc_defined)
print(avg_sorry_high_ssc_defined)
print(avg_emotion_visibility_high_ssc_defined)

print("Low Defined")
print(avg_depressed_low_ssc_defined)
print(avg_tense_low_ssc_defined)
print(avg_dissatisfied_low_ssc_defined)
print(avg_anxious_low_ssc_defined)
print(avg_sorry_low_ssc_defined)
print(avg_emotion_visibility_low_ssc_defined)
# Out:
# High Characteristics
# 3.65625
# 8.166666666666666
# 6.21875
# 6.208333333333333
# 3.46875
# 7.1875
# Low Characteristics
# 20.125
# 37.197916666666664
# 28.958333333333332
# 38.395833333333336
# 11.135416666666666
# 39.677083333333336
# High Defined
# 3.7395833333333335
# 7.322916666666667
# 5.979166666666667
# 5.864583333333333
# 3.4791666666666665
# 5.614583333333333
# Low Defined
# 13.645833333333334
# 22.364583333333332
# 18.208333333333332
# 20.635416666666668
# 11.03125
# 30.291666666666668

# %%
RESULTS_SHORT_STORY = "csv/output/Report_Shorts_with_summary_gregor_short-story_experiment_results_cleaned.csv"

df_shorts = pd.read_csv(RESULTS_SHORT_STORY, sep=",")

results = {}
results['low_ssc_characteristics'] = []
results['high_ssc_characteristics'] = []
results['low_ssc_defined'] = []
results['high_ssc_defined'] = []

total_enjoyment_low_ssc_characteristics = 0
total_fun_low_ssc_characteristics = 0
total_moving_low_ssc_characteristics = 0
total_impression_low_ssc_characteristics = 0
total_suspense_low_ssc_characteristics = 0
total_transportation_low_ssc_characteristics = 0
total_identification_low_ssc_characteristics = 0

total_enjoyment_high_ssc_characteristics = 0
total_fun_high_ssc_characteristics = 0
total_moving_high_ssc_characteristics = 0
total_impression_high_ssc_characteristics = 0
total_suspense_high_ssc_characteristics = 0
total_transportation_high_ssc_characteristics = 0
total_identification_high_ssc_characteristics = 0

total_enjoyment_low_ssc_defined = 0
total_fun_low_ssc_defined = 0
total_moving_low_ssc_defined = 0
total_impression_low_ssc_defined = 0
total_suspense_low_ssc_defined = 0
total_transportation_low_ssc_defined = 0
total_identification_low_ssc_defined = 0

total_enjoyment_high_ssc_defined = 0
total_fun_high_ssc_defined = 0
total_moving_high_ssc_defined = 0
total_impression_high_ssc_defined = 0
total_suspense_high_ssc_defined = 0
total_transportation_high_ssc_defined = 0
total_identification_high_ssc_defined = 0

for index, row in df_shorts.iterrows():
    results['low_ssc_characteristics'].append(json.loads(row['low ssc characteristics']))
    results['high_ssc_characteristics'].append(json.loads(row['high ssc characteristics']))
    results['low_ssc_defined'].append(json.loads(row['low ssc defined']))
    results['high_ssc_defined'].append(json.loads(row['high ssc defined']))

for i in range(0,len(results['low_ssc_characteristics'])):
    total_enjoyment_low_ssc_characteristics += results['low_ssc_characteristics'][i]["enjoyment"]
    total_fun_low_ssc_characteristics += results['low_ssc_characteristics'][i]["fun"]
    total_moving_low_ssc_characteristics += results['low_ssc_characteristics'][i]["moving"]
    total_impression_low_ssc_characteristics += results['low_ssc_characteristics'][i]["impression"]
    total_suspense_low_ssc_characteristics += results['low_ssc_characteristics'][i]["suspense"]
    total_transportation_low_ssc_characteristics += results['low_ssc_characteristics'][i]["transportation"]
    total_identification_low_ssc_characteristics += results['low_ssc_characteristics'][i]["identification"]

    total_enjoyment_high_ssc_characteristics += results['high_ssc_characteristics'][i]["enjoyment"]
    total_fun_high_ssc_characteristics += results['high_ssc_characteristics'][i]["fun"]
    total_moving_high_ssc_characteristics += results['high_ssc_characteristics'][i]["moving"]
    total_impression_high_ssc_characteristics += results['high_ssc_characteristics'][i]["impression"]
    total_suspense_high_ssc_characteristics += results['high_ssc_characteristics'][i]["suspense"]
    total_transportation_high_ssc_characteristics += results['high_ssc_characteristics'][i]["transportation"]
    total_identification_high_ssc_characteristics += results['high_ssc_characteristics'][i]["identification"]

    total_enjoyment_low_ssc_defined += results['low_ssc_defined'][i]["enjoyment"]
    total_fun_low_ssc_defined += results['low_ssc_defined'][i]["fun"]
    total_moving_low_ssc_defined += results['low_ssc_defined'][i]["moving"]
    total_impression_low_ssc_defined += results['low_ssc_defined'][i]["impression"]
    total_suspense_low_ssc_defined += results['low_ssc_defined'][i]["suspense"]
    total_transportation_low_ssc_defined += results['low_ssc_defined'][i]["transportation"]
    total_identification_low_ssc_defined += results['low_ssc_defined'][i]["identification"]

    total_enjoyment_high_ssc_defined += results['high_ssc_defined'][i]["enjoyment"]
    total_fun_high_ssc_defined += results['high_ssc_defined'][i]["fun"]
    total_moving_high_ssc_defined += results['high_ssc_defined'][i]["moving"]
    total_impression_high_ssc_defined += results['high_ssc_defined'][i]["impression"]
    total_suspense_high_ssc_defined += results['high_ssc_defined'][i]["suspense"]
    total_transportation_high_ssc_defined += results['high_ssc_defined'][i]["transportation"]
    total_identification_high_ssc_defined += results['high_ssc_defined'][i]["identification"]

avg_enjoyment_low_ssc_characteristics = total_enjoyment_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_fun_low_ssc_characteristics = total_fun_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_moving_low_ssc_characteristics = total_moving_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_impression_low_ssc_characteristics = total_impression_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_suspense_low_ssc_characteristics = total_suspense_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_transportation_low_ssc_characteristics = total_transportation_low_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_identification_low_ssc_characteristics = total_identification_low_ssc_characteristics/len(results['low_ssc_characteristics'])

avg_enjoyment_high_ssc_characteristics = total_enjoyment_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_fun_high_ssc_characteristics = total_fun_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_moving_high_ssc_characteristics = total_moving_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_impression_high_ssc_characteristics = total_impression_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_suspense_high_ssc_characteristics = total_suspense_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_transportation_high_ssc_characteristics = total_transportation_high_ssc_characteristics/len(results['low_ssc_characteristics'])
avg_identification_high_ssc_characteristics = total_identification_high_ssc_characteristics/len(results['low_ssc_characteristics'])

avg_enjoyment_low_ssc_defined = total_enjoyment_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_fun_low_ssc_defined = total_fun_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_moving_low_ssc_defined = total_moving_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_impression_low_ssc_defined = total_impression_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_suspense_low_ssc_defined = total_suspense_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_transportation_low_ssc_defined = total_transportation_low_ssc_defined/len(results['low_ssc_characteristics'])
avg_identification_low_ssc_defined = total_identification_low_ssc_defined/len(results['low_ssc_characteristics'])

avg_enjoyment_high_ssc_defined = total_enjoyment_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_fun_high_ssc_defined = total_fun_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_moving_high_ssc_defined = total_moving_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_impression_high_ssc_defined = total_impression_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_suspense_high_ssc_defined = total_suspense_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_transportation_high_ssc_defined = total_transportation_high_ssc_defined/len(results['low_ssc_characteristics'])
avg_identification_high_ssc_defined = total_identification_high_ssc_defined/len(results['low_ssc_characteristics'])

plt.rcParams.update({'font.size': 7})

x = np.arange(7)
y1 = [avg_enjoyment_high_ssc_characteristics, avg_fun_high_ssc_characteristics, avg_moving_high_ssc_characteristics,
      avg_impression_high_ssc_characteristics, avg_suspense_high_ssc_characteristics, avg_transportation_high_ssc_characteristics, avg_identification_high_ssc_characteristics]
y2 = [avg_enjoyment_low_ssc_characteristics, avg_fun_low_ssc_characteristics, avg_moving_low_ssc_characteristics,
      avg_impression_low_ssc_characteristics, avg_suspense_low_ssc_characteristics, avg_transportation_low_ssc_characteristics, avg_identification_low_ssc_characteristics]
width = 0.2

plt.bar(x-0.1,y1, width, color='lightseagreen')
plt.bar(x+0.1,y2, width, color='seagreen')
plt.xticks(x, ['Enjoyment', 'Fun', 'Moving', 'Impression', 'Suspense', 'Transportation','Identification'])
plt.legend(["High SSC", "Low SSC "]) 
plt.savefig('short-story_ssc_characteristics.png', dpi=1000)
plt.show()

x = np.arange(7)
y1 = [avg_enjoyment_high_ssc_defined, avg_fun_high_ssc_defined, avg_moving_high_ssc_defined,
      avg_impression_high_ssc_defined, avg_suspense_high_ssc_defined, avg_transportation_high_ssc_defined, avg_identification_high_ssc_defined]
y2 = [avg_enjoyment_low_ssc_defined, avg_fun_low_ssc_defined, avg_moving_low_ssc_defined,
      avg_impression_low_ssc_defined, avg_suspense_low_ssc_defined, avg_transportation_low_ssc_defined, avg_identification_low_ssc_defined]
width = 0.2

plt.bar(x-0.1,y1, width, color='lightseagreen')
plt.bar(x+0.1,y2, width, color='seagreen')
plt.xticks(x, ['Enjoyment', 'Fun', 'Moving', 'Impression', 'Suspense', 'Transportation','Identification'])
plt.legend(["High SSC", "Low SSC "]) 
plt.savefig('short-story_ssc_defined.png', dpi=1000)
plt.show()

print("High Characteristics")
print(avg_enjoyment_high_ssc_characteristics)
print(avg_fun_high_ssc_characteristics)
print(avg_moving_high_ssc_characteristics)
print(avg_impression_high_ssc_characteristics)
print(avg_suspense_high_ssc_characteristics)
print(avg_transportation_high_ssc_characteristics)
print(avg_identification_high_ssc_characteristics)

print("Low Characteristics")
print(avg_enjoyment_low_ssc_characteristics)
print(avg_fun_low_ssc_characteristics)
print(avg_moving_low_ssc_characteristics)
print(avg_impression_low_ssc_characteristics)
print(avg_suspense_low_ssc_characteristics)
print(avg_transportation_low_ssc_characteristics)
print(avg_identification_low_ssc_characteristics)

print("High Defined")
print(avg_enjoyment_high_ssc_defined)
print(avg_fun_high_ssc_defined)
print(avg_moving_high_ssc_defined)
print(avg_impression_high_ssc_defined)
print(avg_suspense_high_ssc_defined)
print(avg_transportation_high_ssc_defined)
print(avg_identification_high_ssc_defined)

print("Low Defined")
print(avg_enjoyment_low_ssc_defined)
print(avg_fun_low_ssc_defined)
print(avg_moving_low_ssc_defined)
print(avg_impression_low_ssc_defined)
print(avg_suspense_low_ssc_defined)
print(avg_transportation_low_ssc_defined)
print(avg_identification_low_ssc_defined)
# Out:
# High Characteristics
# 3.38
# 3.23
# 2.24
# 3.54
# 1.82
# 2.4
# 2.37
# Low Characteristics
# 3.18
# 3.56
# 1.93
# 3.24
# 1.59
# 2.17
# 2.39
# High Defined
# 3.44
# 3.25
# 2.27
# 3.52
# 1.89
# 2.45
# 2.51
# Low Defined
# 2.96
# 2.85
# 1.63
# 2.56
# 1.51
# 1.75
# 2.0
